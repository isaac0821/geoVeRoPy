# %%
import sys
sys.path.append("../../geoVeRoPy")
import geoVeRoPy
import shapely
import matplotlib.pyplot as plt

import math
import random
# %matplotlib notebook

# %% [markdown]
# # Randomly create customer locations

# %% [markdown]
# ### Distr = 'UniformSquareXY' (default)

# %%
nodes = geoVeRoPy.rndNodes(N = 10)
# Out:
# /media/lan-peng/HDisk/Zoo/Gull/geoVeRoPy/demo/../../geoVeRoPy/geoVeRoPy/instance.py:83: UserWarning: WARNING: Set sampled area to be default as a (0, 100) x (0, 100) square
#   warnings.warn("WARNING: Set sampled area to be default as a (0, 100) x (0, 100) square")

# %%
fig, ax = geoVeRoPy.plotNodes(
    nodes = nodes,
    boundingBox = (0, 100, 0, 100))

# %%
nodes = geoVeRoPy.rndNodes(N = 10, xRange = [-100, 100], yRange = [-100, 100])

# %%
fig, ax = geoVeRoPy.plotNodes(
    nodes = nodes,
    boundingBox = (-100, 100, -100, 100))
